# %%
#Headers and libraries that we're gonna use

# %matplotlib inline
#print(__doc__)

import numpy as np # We need NumPy in order to work with arrays which we'll use to order our data
import matplotlib.pyplot as plt # Matplotlib will be used for all the plots that we will make
from sklearn.utils.validation import check_random_state #to put a global seed for random number generator
from tutorial import plot_clf

#Regressor algorithms
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

#Classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.metrics import zero_one_loss
from sklearn.model_selection import train_test_split

# %%
import csv
photo_names = []
photos = []
tags = []

with open('training_solutions_rev1.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    i = 0
    restrictor = 10000
    for row in reader:
        if (restrictor > 0):
            if i >1:
                a = float(row[1])
                b = float(row[2])
                c = float(row[3])
                suma = a+b+c
                
                a = float(a)/float(suma)
                b = float(b)/float(suma)
                c = float(c)/float(suma)
                
                maxim = np.max([a, b, c])
                
                if (maxim >= 0.5):
                    if (maxim == a):
                        photo_names.append(row[0])
                        tag = "smooth"
                        tags.append([tag, row[0]])
                    elif (maxim == b):
                        photo_names.append(row[0])
                        tag = "features"
                        tags.append([tag, row[0]])
                    else:
                        tag = "point"
                
            i += 1
            restrictor -= 1
        

print(len(photo_names))
       
import scipy.misc as scp_misc
restrictor = 10000
for photo in photo_names:
    if (restrictor > 0):
        img = scp_misc.imread("images_training_rev1/"+photo+".jpg", mode="L")
        img = scp_misc.imresize(img, 25)
        photos.append(img)
        restrictor -= 1
# Out:
# 9741

# %%
a = 0
while (a < len(photos)):
    photos[a] = np.reshape(photos[a], -1)
    a += 1

# %% [markdown]
# Now let's divide the samples into training and test samples. *Comment*: maybe we should massage the y sample.

# %%
X = photos
y = tags
X_train, X_test, y_train, y_test = train_test_split(X, y)

clf = RandomForestClassifier(n_estimators=500)

y_test_id = []
y_test_v = []
y_train_id = []
y_train_v = []
 
for value in range(len(y_test)):
    y_test_id.append(y_test[value][1])
    y_test_v.append(y_test[value][0])
for value in range(len(y_train)):
    y_train_id.append(y_train[value][1])
    y_train_v.append(y_train[value][0])

y_test_predict = dict()
clf.fit(X_train, y_train_v)
y_test_predict = clf.predict(X_test)

# %%
y2 = []
print len(y)
for value in range(len(y)):
    y2.append(y[value][0])
# Out:
# 9741

# %%
for hoho in range(len(y_test_id)):
    print([y_test_predict[hoho], y_test_id[hoho]], y_test_v[hoho])
# Out:
# (['features', '125537'], 'features')
# (['features', '218483'], 'features')
# (['features', '195013'], 'features')
# (['smooth', '188099'], 'smooth')
# (['features', '110411'], 'smooth')
# (['features', '123628'], 'smooth')
# (['smooth', '227470'], 'features')
# (['features', '125739'], 'smooth')
# (['features', '225923'], 'features')
# (['features', '107745'], 'features')
# (['features', '226024'], 'features')
# (['features', '160999'], 'features')
# (['features', '110678'], 'features')
# (['smooth', '126656'], 'features')
# (['smooth', '150472'], 'smooth')
# (['smooth', '240952'], 'smooth')
# (['smooth', '175164'], 'smooth')
# (['smooth', '133503'], 'smooth')
# (['smooth', '242893'], 'smooth')
# (['smooth', '211561'], 'smooth')
# (['smooth', '234868'], 'smooth')
# (['features', '124981'], 'features')
# (['smooth', '214780'], 'smooth')
# (['features', '121946'], 'smooth')
# (['features', '207139'], 'features')
# (['features', '135766'], 'features')
# (['features', '236953'], 'features')
# (['features', '198344'], 'smooth')
# (['features', '239841'], 'features')
# (['smooth', '239918'], 'smooth')
# (['features', '139665'], 'features')
# (['smooth', '169522'], 'smooth')
# (['smooth', '231792'], 'features')
# (['smooth', '219648'], 'features')
# (['smooth', '126800'], 'smooth')
# (['features', '208631'], 'features')
# (['smooth', '232031'], 'smooth')
# (['features', '161215'], 'features')
# (['smooth', '147111'], 'smooth')
# (['features', '194519'], 'features')
# (['smooth', '170629'], 'features')
# (['features', '137150'], 'smooth')
# (['features', '171613'], 'features')
# (['features', '102159'], 'features')
# (['smooth', '224770'], 'features')
# (['features', '216306'], 'features')
# (['features', '156214'], 'features')
# (['smooth', '172649'], 'smooth')
# (['smooth', '201119'], 'features')
# (['features', '236104'], 'features')
# (['smooth', '114294'], 'smooth')
# (['features', '177737'], 'features')
# (['smooth', '149603'], 'smooth')
# (['features', '197852'], 'features')
# (['smooth', '182884'], 'smooth')
# (['features', '143402'], 'features')
# (['features', '226639'], 'features')
# (['smooth', '184718'], 'smooth')
# (['features', '167086'], 'features')
# (['features', '201603'], 'features')
# (['features', '227057'], 'features')
# (['features', '185229'], 'smooth')
# (['smooth', '233513'], 'features')
# (['smooth', '112819'], 'smooth')
# (['features', '221150'], 'features')
# (['features', '230491'], 'smooth')
# (['smooth', '245955'], 'smooth')
# (['features', '114059'], 'features')
# (['features', '174852'], 'features')
# (['features', '137969'], 'smooth')
# (['smooth', '214933'], 'smooth')
# (['features', '176298'], 'features')
# (['features', '101848'], 'features')
# (['smooth', '229832'], 'smooth')
# (['features', '220050'], 'features')
# (['features', '136592'], 'smooth')
# (['features', '136382'], 'features')
# (['features', '135043'], 'features')
# (['features', '192969'], 'features')
# (['features', '159820'], 'smooth')
# (['features', '195428'], 'features')
# (['features', '122068'], 'features')
# (['features', '190867'], 'features')
# (['features', '138360'], 'smooth')
# (['features', '235028'], 'features')
# (['smooth', '159174'], 'smooth')
# (['smooth', '209196'], 'features')
# (['smooth', '197100'], 'features')
# (['smooth', '118941'], 'features')
# (['smooth', '119398'], 'smooth')
# (['features', '192542'], 'features')
# (['smooth', '158414'], 'smooth')
# (['features', '223408'], 'features')
# (['features', '241858'], 'features')
# (['features', '182053'], 'smooth')
# (['features', '177327'], 'features')
# (['features', '242925'], 'smooth')
# (['features', '164198'], 'smooth')
# (['features', '130394'], 'features')
# (['smooth', '235683'], 'smooth')
# (['smooth', '156283'], 'smooth')
# (['smooth', '158651'], 'smooth')
# (['smooth', '136385'], 'smooth')
# (['features', '211628'], 'smooth')
# (['smooth', '215451'], 'features')
# (['smooth', '106819'], 'features')
# (['features', '191131'], 'smooth')
# (['features', '192724'], 'smooth')
# (['smooth', '235079'], 'smooth')
# (['smooth', '232145'], 'smooth')
# (['features', '143163'], 'smooth')
# (['smooth', '219175'], 'features')
# (['smooth', '134798'], 'smooth')
# (['features', '160870'], 'smooth')
# (['features', '200173'], 'smooth')
# (['features', '147715'], 'features')
# (['features', '103999'], 'features')
# (['features', '109074'], 'smooth')
# (['features', '204788'], 'features')
# (['smooth', '223193'], 'smooth')
# (['features', '154549'], 'features')
# (['features', '136264'], 'features')
# (['smooth', '245983'], 'smooth')
# (['smooth', '157234'], 'smooth')
# (['features', '130972'], 'features')
# (['features', '173031'], 'features')
# (['smooth', '161583'], 'smooth')
# (['features', '139352'], 'features')
# (['features', '109422'], 'features')
# (['features', '160720'], 'features')
# (['smooth', '141957'], 'smooth')
# (['features', '162740'], 'features')
# (['features', '121552'], 'features')
# (['features', '113566'], 'smooth')
# (['smooth', '102271'], 'features')
# (['features', '114896'], 'features')
# (['features', '243825'], 'features')
# (['features', '169530'], 'features')
# (['features', '149577'], 'features')
# (['features', '111622'], 'features')
# (['features', '228473'], 'features')
# (['features', '139015'], 'features')
# (['features', '107422'], 'features')
# (['features', '108088'], 'features')
# (['smooth', '216111'], 'features')
# (['features', '120629'], 'smooth')
# (['features', '209657'], 'features')
# (['features', '132782'], 'features')
# (['smooth', '189761'], 'smooth')
# (['features', '212123'], 'features')
# (['features', '123498'], 'features')
# (['smooth', '108645'], 'smooth')
# (['features', '100122'], 'smooth')
# (['features', '128650'], 'features')
# (['features', '240944'], 'features')
# (['features', '156819'], 'smooth')
# (['features', '233385'], 'features')
# (['features', '123772'], 'features')
# (['features', '217874'], 'features')
# (['smooth', '198740'], 'smooth')
# (['smooth', '122294'], 'features')
# (['features', '162608'], 'features')
# (['features', '207877'], 'features')
# (['features', '162498'], 'features')
# (['features', '183349'], 'features')
# (['smooth', '134681'], 'smooth')
# (['features', '125616'], 'features')
# (['features', '247310'], 'features')
# (['features', '239782'], 'features')
# (['features', '242367'], 'features')
# (['smooth', '133289'], 'smooth')
# (['features', '208293'], 'features')
# (['features', '150402'], 'features')
# (['smooth', '168825'], 'features')
# (['smooth', '163755'], 'smooth')
# (['features', '243519'], 'features')
# (['features', '207758'], 'smooth')
# (['smooth', '173863'], 'smooth')
# (['smooth', '247347'], 'smooth')
# (['smooth', '221902'], 'smooth')
# (['smooth', '104988'], 'smooth')
# (['smooth', '159369'], 'smooth')
# (['features', '238357'], 'features')
# (['features', '172411'], 'smooth')
# (['features', '188755'], 'features')
# (['smooth', '240040'], 'smooth')
# (['features', '107616'], 'features')
# (['features', '229698'], 'features')
# (['smooth', '121250'], 'smooth')
# (['smooth', '227732'], 'features')
# (['smooth', '202139'], 'features')
# (['features', '138869'], 'smooth')
# (['features', '229433'], 'features')
# (['features', '151329'], 'features')
# (['features', '126427'], 'features')
# (['smooth', '144881'], 'smooth')
# (['features', '201198'], 'smooth')
# (['features', '209902'], 'features')
# (['smooth', '222735'], 'features')
# (['features', '222387'], 'features')
# (['features', '161884'], 'smooth')
# (['features', '176101'], 'features')
# (['smooth', '121769'], 'smooth')
# (['features', '177506'], 'features')
# (['features', '216766'], 'features')
# (['features', '230885'], 'features')
# (['features', '137578'], 'features')
# (['smooth', '189972'], 'features')
# (['features', '197161'], 'features')
# (['features', '159137'], 'smooth')
# (['smooth', '106463'], 'smooth')
# (['smooth', '239937'], 'smooth')
# (['features', '122477'], 'features')
# (['smooth', '186249'], 'smooth')
# (['features', '124477'], 'features')
# (['features', '231232'], 'features')
# (['features', '194410'], 'features')
# (['features', '169340'], 'features')
# (['features', '213567'], 'features')
# (['features', '137384'], 'features')
# (['features', '108326'], 'features')
# (['features', '194459'], 'smooth')
# (['features', '182036'], 'features')
# (['features', '220284'], 'features')
# (['features', '160809'], 'features')
# (['features', '168395'], 'features')
# (['features', '244474'], 'smooth')
# (['smooth', '143730'], 'smooth')
# (['features', '226994'], 'features')
# (['features', '179859'], 'features')
# (['smooth', '110306'], 'smooth')
# (['smooth', '115891'], 'smooth')
# (['smooth', '203478'], 'smooth')
# (['features', '101127'], 'features')
# (['features', '154002'], 'features')
# (['features', '173373'], 'features')
# (['smooth', '167857'], 'smooth')
# (['features', '246163'], 'smooth')
# (['features', '162640'], 'features')
# (['features', '232631'], 'features')
# (['features', '107466'], 'features')
# (['smooth', '120201'], 'smooth')
# (['smooth', '204026'], 'smooth')
# (['smooth', '218190'], 'smooth')
# (['features', '245954'], 'smooth')
# (['features', '124908'], 'smooth')
# (['features', '230169'], 'features')
# (['features', '228417'], 'features')
# (['features', '243157'], 'features')
# (['smooth', '132153'], 'features')
# (['smooth', '111839'], 'smooth')
# (['features', '198897'], 'features')
# (['features', '125860'], 'features')
# (['features', '159880'], 'smooth')
# (['features', '163221'], 'features')
# (['features', '132416'], 'smooth')
# (['features', '101286'], 'smooth')
# (['smooth', '127031'], 'smooth')
# (['features', '211990'], 'features')
# (['features', '146348'], 'features')
# (['smooth', '180897'], 'smooth')
# (['features', '216622'], 'features')
# (['smooth', '236965'], 'features')
# (['smooth', '227724'], 'smooth')
# (['smooth', '229659'], 'features')
# (['features', '115597'], 'smooth')
# (['features', '136247'], 'smooth')
# (['features', '177342'], 'features')
# (['smooth', '176499'], 'smooth')
# (['features', '104420'], 'features')
# (['features', '184924'], 'features')
# (['features', '242140'], 'features')
# (['features', '110250'], 'smooth')
# (['features', '233198'], 'features')
# (['smooth', '115051'], 'smooth')
# (['features', '207014'], 'features')
# (['smooth', '248289'], 'smooth')
# (['features', '216483'], 'features')
# (['smooth', '187666'], 'smooth')
# (['smooth', '117192'], 'smooth')
# (['smooth', '174068'], 'smooth')
# (['smooth', '137587'], 'smooth')
# (['features', '116064'], 'features')
# (['features', '242262'], 'smooth')
# (['features', '177708'], 'features')
# (['features', '198199'], 'features')
# (['smooth', '117217'], 'features')
# (['features', '195557'], 'features')
# (['features', '230141'], 'features')
# (['features', '181705'], 'features')
# (['features', '118539'], 'features')
# (['features', '231052'], 'smooth')
# (['features', '186721'], 'features')
# (['smooth', '152297'], 'features')
# (['features', '125577'], 'features')
# (['smooth', '204152'], 'smooth')
# (['smooth', '143858'], 'smooth')
# (['features', '180540'], 'features')
# (['features', '130097'], 'features')
# (['features', '121262'], 'smooth')
# (['smooth', '161031'], 'smooth')
# (['features', '228433'], 'features')
# (['smooth', '140167'], 'features')
# (['features', '148106'], 'features')
# (['smooth', '192111'], 'smooth')
# (['smooth', '140489'], 'smooth')
# (['features', '234961'], 'features')
# (['smooth', '167613'], 'smooth')
# (['features', '106621'], 'features')
# (['features', '218541'], 'features')
# (['features', '199693'], 'features')
# (['smooth', '157023'], 'smooth')
# (['features', '198191'], 'features')
# (['features', '182956'], 'features')
# (['features', '185898'], 'features')
# (['smooth', '144810'], 'features')
# (['features', '148863'], 'features')
# (['features', '144158'], 'features')
# (['smooth', '151545'], 'smooth')
# (['features', '230350'], 'features')
# (['features', '185121'], 'smooth')
# (['smooth', '144756'], 'features')
# (['features', '176748'], 'features')
# (['features', '141586'], 'features')
# (['features', '182551'], 'features')
# (['features', '229116'], 'smooth')
# (['features', '243024'], 'features')
# (['features', '130226'], 'smooth')
# (['smooth', '232843'], 'smooth')
# (['features', '190346'], 'smooth')
# (['smooth', '132280'], 'smooth')
# (['features', '209641'], 'features')
# (['features', '150942'], 'features')
# (['smooth', '247582'], 'smooth')
# (['features', '240362'], 'features')
# (['features', '103592'], 'features')
# (['features', '143414'], 'features')
# (['smooth', '103260'], 'smooth')
# (['smooth', '112665'], 'features')
# (['smooth', '149364'], 'smooth')
# (['features', '207952'], 'features')
# (['smooth', '140246'], 'smooth')
# (['features', '154604'], 'features')
# (['features', '247147'], 'smooth')
# (['smooth', '153381'], 'smooth')
# (['features', '206256'], 'features')
# (['features', '248017'], 'smooth')
# (['features', '221172'], 'features')
# (['features', '220161'], 'features')
# (['features', '198664'], 'features')
# (['smooth', '240021'], 'smooth')
# (['features', '181054'], 'features')
# (['features', '182177'], 'smooth')
# (['smooth', '130803'], 'smooth')
# (['features', '179420'], 'features')
# (['smooth', '191537'], 'features')
# (['smooth', '128720'], 'smooth')
# (['smooth', '127788'], 'smooth')
# (['features', '215276'], 'features')
# (['smooth', '233237'], 'features')
# (['features', '235613'], 'features')
# (['smooth', '165688'], 'features')
# (['features', '195598'], 'features')
# (['smooth', '212091'], 'features')
# (['smooth', '235053'], 'smooth')
# (['features', '224587'], 'features')
# (['smooth', '233139'], 'smooth')
# (['features', '134742'], 'features')
# (['features', '205024'], 'smooth')
# (['smooth', '236508'], 'smooth')
# (['smooth', '126282'], 'smooth')
# (['features', '244361'], 'smooth')
# (['features', '101358'], 'features')
# (['features', '235544'], 'features')
# (['smooth', '195644'], 'smooth')
# (['features', '156879'], 'features')
# (['features', '229223'], 'features')
# (['features', '119010'], 'features')
# (['features', '179054'], 'features')
# (['smooth', '245293'], 'smooth')
# (['features', '136667'], 'features')
# (['features', '243112'], 'features')
# (['features', '145443'], 'features')
# (['smooth', '187884'], 'smooth')
# (['features', '206275'], 'features')
# (['features', '160832'], 'features')
# (['features', '102871'], 'smooth')
# (['features', '141491'], 'features')
# (['smooth', '236587'], 'smooth')
# (['smooth', '187656'], 'smooth')
# (['smooth', '183742'], 'features')
# (['smooth', '224721'], 'smooth')
# (['features', '198169'], 'smooth')
# (['features', '142331'], 'features')
# (['features', '180204'], 'features')
# (['features', '216032'], 'features')
# (['features', '179774'], 'smooth')
# (['features', '190745'], 'smooth')
# (['smooth', '191200'], 'smooth')
# (['features', '201335'], 'smooth')
# (['features', '184221'], 'smooth')
# (['smooth', '169311'], 'smooth')
# (['features', '127297'], 'smooth')
# (['smooth', '225760'], 'smooth')
# (['features', '113692'], 'features')
# (['features', '143776'], 'smooth')
# (['smooth', '234904'], 'smooth')
# (['features', '211666'], 'features')
# (['smooth', '208628'], 'smooth')
# (['smooth', '220490'], 'features')
# (['features', '156525'], 'smooth')
# (['features', '169407'], 'features')
# (['smooth', '209064'], 'features')
# (['features', '189022'], 'smooth')
# (['features', '223881'], 'features')
# (['features', '181649'], 'features')
# (['features', '153202'], 'features')
# (['features', '211803'], 'features')
# (['features', '118723'], 'features')
# (['features', '238668'], 'features')
# (['features', '199124'], 'features')
# (['features', '237182'], 'features')
# (['features', '221555'], 'features')
# (['features', '218573'], 'features')
# (['features', '185073'], 'features')
# (['features', '185768'], 'features')
# (['features', '130553'], 'features')
# (['smooth', '131184'], 'smooth')
# (['smooth', '131054'], 'smooth')
# (['features', '151417'], 'features')
# (['features', '156206'], 'smooth')
# (['smooth', '100861'], 'smooth')
# (['features', '153767'], 'features')
# (['smooth', '177789'], 'smooth')
# (['smooth', '179458'], 'smooth')
# (['smooth', '186968'], 'smooth')
# (['smooth', '148223'], 'smooth')
# (['features', '233759'], 'smooth')
# (['smooth', '154426'], 'features')
# (['features', '242964'], 'features')
# (['features', '219963'], 'features')
# (['features', '222158'], 'features')
# (['features', '114046'], 'smooth')
# (['features', '178814'], 'features')
# (['features', '215734'], 'features')
# (['smooth', '213936'], 'smooth')
# (['features', '247875'], 'features')
# (['features', '103040'], 'features')
# (['features', '123308'], 'features')
# (['features', '121746'], 'features')
# (['smooth', '135359'], 'smooth')
# (['features', '192472'], 'features')
# (['smooth', '234835'], 'smooth')
# (['features', '208394'], 'features')
# (['features', '169728'], 'features')
# (['features', '201535'], 'features')
# (['smooth', '173383'], 'features')
# (['features', '192168'], 'features')
# (['features', '187996'], 'features')
# (['smooth', '241468'], 'smooth')
# (['features', '108012'], 'features')
# (['features', '200057'], 'features')
# (['smooth', '106044'], 'smooth')
# (['features', '187737'], 'features')
# (['features', '224768'], 'features')
# (['features', '244469'], 'smooth')
# (['features', '153389'], 'features')
# (['smooth', '217762'], 'features')
# (['features', '188431'], 'features')
# (['smooth', '214624'], 'smooth')
# (['features', '197296'], 'features')
# (['smooth', '205475'], 'smooth')
# (['features', '207975'], 'features')
# (['features', '155769'], 'features')
# (['features', '215499'], 'features')
# (['features', '209734'], 'features')
# (['features', '106803'], 'features')
# (['features', '248398'], 'features')
# (['features', '139040'], 'features')
# (['features', '239507'], 'features')
# (['features', '141392'], 'features')
# (['features', '131103'], 'features')
# (['smooth', '121811'], 'smooth')
# (['features', '209994'], 'features')
# (['features', '242574'], 'features')
# (['features', '196815'], 'features')
# (['smooth', '215581'], 'smooth')
# (['features', '172616'], 'features')
# (['features', '246739'], 'features')
# (['smooth', '113746'], 'smooth')
# (['features', '227476'], 'smooth')
# (['smooth', '230086'], 'features')
# (['features', '209998'], 'features')
# (['features', '190331'], 'features')
# (['features', '203648'], 'features')
# (['features', '236034'], 'features')
# (['smooth', '127027'], 'smooth')
# (['smooth', '226045'], 'features')
# (['features', '125934'], 'features')
# (['features', '186921'], 'features')
# (['features', '138236'], 'features')
# (['smooth', '232957'], 'smooth')
# (['features', '133994'], 'features')
# (['features', '244523'], 'features')
# (['features', '134170'], 'smooth')
# (['smooth', '241964'], 'smooth')
# (['features', '176756'], 'smooth')
# (['features', '131874'], 'smooth')
# (['features', '240041'], 'features')
# (['smooth', '199258'], 'smooth')
# (['features', '220076'], 'features')
# (['features', '226370'], 'smooth')
# (['smooth', '217984'], 'smooth')
# (['features', '226867'], 'features')
# (['features', '123093'], 'features')
# (['features', '100541'], 'features')
# (['features', '136569'], 'features')
# (['features', '180068'], 'features')
# (['features', '127386'], 'features')
# (['smooth', '196842'], 'smooth')
# (['smooth', '165086'], 'features')
# (['features', '201587'], 'features')
# (['features', '108584'], 'smooth')
# (['smooth', '194028'], 'smooth')
# (['smooth', '220954'], 'smooth')
# (['features', '233132'], 'features')
# (['smooth', '243770'], 'smooth')
# (['smooth', '222815'], 'smooth')
# (['features', '122705'], 'smooth')
# (['features', '107794'], 'smooth')
# (['features', '222596'], 'smooth')
# (['features', '201046'], 'features')
# (['features', '200547'], 'features')
# (['features', '244665'], 'smooth')
# (['features', '180130'], 'features')
# (['smooth', '219489'], 'smooth')
# (['features', '183771'], 'features')
# (['features', '127730'], 'features')
# (['features', '242011'], 'features')
# (['smooth', '158900'], 'smooth')
# (['features', '150645'], 'features')
# (['smooth', '165924'], 'smooth')
# (['features', '160439'], 'features')
# (['features', '225516'], 'features')
# (['features', '111770'], 'features')
# (['smooth', '187938'], 'smooth')
# (['features', '169790'], 'smooth')
# (['smooth', '156053'], 'smooth')
# (['smooth', '102616'], 'smooth')
# (['features', '138815'], 'features')
# (['features', '166276'], 'features')
# (['smooth', '145608'], 'features')
# (['features', '145835'], 'features')
# (['smooth', '188405'], 'smooth')
# (['smooth', '204591'], 'smooth')
# (['smooth', '181800'], 'smooth')
# (['smooth', '217340'], 'smooth')
# (['features', '191076'], 'features')
# (['features', '175379'], 'features')
# (['smooth', '206475'], 'features')
# (['features', '210656'], 'smooth')
# (['features', '192365'], 'features')
# (['features', '206081'], 'features')
# (['features', '178653'], 'features')
# (['features', '163026'], 'features')
# (['features', '138490'], 'features')
# (['features', '147766'], 'features')
# (['features', '236162'], 'features')
# (['features', '204252'], 'features')
# (['features', '172148'], 'features')
# (['features', '138392'], 'features')
# (['smooth', '151588'], 'smooth')
# (['features', '119699'], 'smooth')
# (['features', '157726'], 'features')
# (['smooth', '228751'], 'smooth')
# (['features', '130996'], 'features')
# (['features', '206769'], 'features')
# (['smooth', '173392'], 'smooth')
# (['features', '202903'], 'features')
# (['features', '103974'], 'features')
# (['smooth', '107403'], 'smooth')
# (['features', '116695'], 'smooth')
# (['smooth', '247570'], 'features')
# (['smooth', '166007'], 'smooth')
# (['features', '116857'], 'features')
# (['smooth', '101943'], 'smooth')
# (['features', '169072'], 'features')
# (['features', '111979'], 'features')
# (['features', '119831'], 'features')
# (['smooth', '209934'], 'smooth')
# (['features', '205043'], 'smooth')
# (['features', '201949'], 'features')
# (['features', '117647'], 'smooth')
# (['features', '239195'], 'features')
# (['smooth', '163435'], 'smooth')
# (['features', '159211'], 'smooth')
# (['features', '233436'], 'features')
# (['smooth', '207060'], 'smooth')
# (['features', '135714'], 'features')
# (['smooth', '212879'], 'smooth')
# (['features', '216716'], 'features')
# (['features', '243145'], 'features')
# (['smooth', '113641'], 'features')
# (['features', '211061'], 'features')
# (['smooth', '128978'], 'smooth')
# (['features', '155564'], 'features')
# (['features', '190158'], 'smooth')
# (['smooth', '156057'], 'features')
# (['smooth', '168795'], 'smooth')
# (['features', '163761'], 'features')
# (['features', '147670'], 'smooth')
# (['features', '234951'], 'smooth')
# (['features', '130026'], 'features')
# (['features', '248466'], 'features')
# (['smooth', '168097'], 'smooth')
# (['features', '158548'], 'features')
# (['smooth', '113444'], 'smooth')
# (['features', '198164'], 'features')
# (['smooth', '160503'], 'smooth')
# (['smooth', '132714'], 'smooth')
# (['features', '243137'], 'features')
# (['smooth', '217049'], 'features')
# (['smooth', '185591'], 'features')
# (['smooth', '245835'], 'smooth')
# (['features', '246623'], 'features')
# (['smooth', '214941'], 'smooth')
# (['features', '121085'], 'features')
# (['smooth', '143187'], 'smooth')
# (['smooth', '185381'], 'smooth')
# (['features', '206807'], 'features')
# (['smooth', '118188'], 'features')
# (['features', '181828'], 'smooth')
# (['features', '180308'], 'features')
# (['smooth', '183976'], 'smooth')
# (['features', '172928'], 'features')
# (['smooth', '232077'], 'smooth')
# (['smooth', '161216'], 'smooth')
# (['features', '233744'], 'features')
# (['smooth', '156813'], 'smooth')
# (['features', '202444'], 'features')
# (['features', '206400'], 'smooth')
# (['smooth', '145879'], 'smooth')
# (['features', '124079'], 'features')
# (['smooth', '210465'], 'smooth')
# (['smooth', '145793'], 'smooth')
# (['smooth', '182046'], 'smooth')
# (['features', '133256'], 'features')
# (['features', '198628'], 'smooth')
# (['features', '120107'], 'smooth')
# (['features', '174245'], 'features')
# (['features', '162538'], 'smooth')
# (['smooth', '204848'], 'smooth')
# (['smooth', '172524'], 'smooth')
# (['smooth', '237494'], 'smooth')
# (['smooth', '132623'], 'smooth')
# (['smooth', '201300'], 'features')
# (['smooth', '114650'], 'smooth')
# (['features', '180814'], 'features')
# (['smooth', '185825'], 'smooth')
# (['features', '191331'], 'smooth')
# (['features', '211774'], 'features')
# (['smooth', '144433'], 'smooth')
# (['features', '141186'], 'features')
# (['features', '169244'], 'smooth')
# (['features', '234689'], 'features')
# (['smooth', '148990'], 'smooth')
# (['features', '184863'], 'features')
# (['features', '147596'], 'features')
# (['smooth', '168197'], 'smooth')
# (['features', '135256'], 'features')
# (['features', '214046'], 'features')
# (['features', '154862'], 'features')
# (['features', '231615'], 'features')
# (['features', '131473'], 'features')
# (['features', '175567'], 'features')
# (['features', '116998'], 'features')
# (['smooth', '224598'], 'smooth')
# (['smooth', '175356'], 'smooth')
# (['features', '166640'], 'smooth')
# (['features', '104287'], 'features')
# (['smooth', '149572'], 'features')
# (['features', '220711'], 'features')
# (['features', '112574'], 'smooth')
# (['features', '200519'], 'features')
# (['smooth', '200876'], 'features')
# (['smooth', '117623'], 'smooth')
# (['features', '235557'], 'features')
# (['smooth', '119554'], 'smooth')
# (['features', '139712'], 'features')
# (['features', '204192'], 'smooth')
# (['features', '110763'], 'features')
# (['features', '170755'], 'smooth')
# (['features', '149922'], 'features')
# (['features', '137862'], 'features')
# (['features', '163008'], 'features')
# (['features', '203121'], 'features')
# (['features', '242247'], 'features')
# (['smooth', '140239'], 'features')
# (['smooth', '230768'], 'smooth')
# (['smooth', '213757'], 'smooth')
# (['smooth', '201776'], 'smooth')
# (['features', '187579'], 'features')
# (['smooth', '168073'], 'smooth')
# (['features', '208309'], 'features')
# (['smooth', '176797'], 'features')
# (['smooth', '244144'], 'smooth')
# (['features', '121067'], 'features')
# (['features', '179122'], 'features')
# (['features', '171301'], 'features')
# (['features', '116265'], 'features')
# (['features', '181531'], 'smooth')
# (['features', '169744'], 'features')
# (['smooth', '198368'], 'smooth')
# (['features', '174354'], 'features')
# (['smooth', '107849'], 'smooth')
# (['smooth', '159810'], 'smooth')
# (['features', '142508'], 'features')
# (['smooth', '141593'], 'smooth')
# (['smooth', '237243'], 'features')
# (['smooth', '132209'], 'smooth')
# (['features', '172677'], 'smooth')
# (['features', '184501'], 'smooth')
# (['features', '125760'], 'features')
# (['features', '132938'], 'features')
# (['features', '162438'], 'features')
# (['smooth', '110370'], 'features')
# (['smooth', '139143'], 'smooth')
# (['features', '189101'], 'features')
# (['smooth', '101298'], 'features')
# (['smooth', '210143'], 'smooth')
# (['smooth', '180393'], 'features')
# (['features', '152406'], 'features')
# (['features', '233179'], 'smooth')
# (['smooth', '175783'], 'features')
# (['smooth', '244264'], 'smooth')
# (['features', '247817'], 'features')
# (['smooth', '171173'], 'features')
# (['features', '152289'], 'features')
# (['features', '179137'], 'smooth')
# (['features', '126260'], 'features')
# (['features', '175888'], 'features')
# (['smooth', '242153'], 'smooth')
# (['features', '146136'], 'features')
# (['smooth', '221064'], 'features')
# (['smooth', '221153'], 'features')
# (['features', '156044'], 'smooth')
# (['smooth', '172879'], 'smooth')
# (['smooth', '132419'], 'smooth')
# (['smooth', '170340'], 'smooth')
# (['features', '171801'], 'smooth')
# (['features', '188569'], 'smooth')
# (['features', '182785'], 'features')
# (['smooth', '215424'], 'smooth')
# (['features', '170106'], 'features')
# (['features', '172743'], 'features')
# (['features', '109688'], 'features')
# (['smooth', '243146'], 'features')
# (['features', '174589'], 'features')
# (['features', '208469'], 'features')
# (['features', '215735'], 'features')
# (['smooth', '115918'], 'smooth')
# (['features', '169190'], 'features')
# (['features', '202147'], 'smooth')
# (['features', '245998'], 'features')
# (['features', '200395'], 'smooth')
# (['features', '196641'], 'features')
# (['features', '153933'], 'features')
# (['features', '228196'], 'features')
# (['features', '218268'], 'features')
# (['smooth', '216168'], 'features')
# (['features', '151884'], 'features')
# (['features', '119321'], 'features')
# (['smooth', '226040'], 'smooth')
# (['features', '186596'], 'features')
# (['features', '106944'], 'features')
# (['features', '247234'], 'features')
# (['smooth', '204167'], 'smooth')
# (['features', '227541'], 'features')
# (['smooth', '137352'], 'smooth')
# (['smooth', '154994'], 'smooth')
# (['features', '128240'], 'features')
# (['features', '158767'], 'features')
# (['features', '126085'], 'features')
# (['smooth', '152219'], 'smooth')
# (['smooth', '184703'], 'smooth')
# (['features', '168158'], 'features')
# (['smooth', '226136'], 'smooth')
# (['features', '223500'], 'features')
# (['features', '148570'], 'features')
# (['features', '198061'], 'features')
# (['features', '245712'], 'features')
# (['features', '144152'], 'features')
# (['features', '112125'], 'features')
# (['features', '160900'], 'features')
# (['features', '239843'], 'features')
# (['features', '223181'], 'smooth')
# (['features', '237716'], 'features')
# (['smooth', '185140'], 'features')
# (['features', '189261'], 'features')
# (['features', '172715'], 'features')
# (['features', '160030'], 'features')
# (['smooth', '225111'], 'features')
# (['features', '137693'], 'features')
# (['features', '190225'], 'features')
# (['features', '172704'], 'features')
# (['features', '157660'], 'features')
# (['smooth', '222884'], 'smooth')
# (['smooth', '140466'], 'smooth')
# (['features', '186699'], 'smooth')
# (['features', '203638'], 'features')
# (['features', '159066'], 'features')
# (['smooth', '152853'], 'smooth')
# (['smooth', '101875'], 'smooth')
# (['features', '154040'], 'features')
# (['features', '134363'], 'smooth')
# (['features', '109449'], 'features')
# (['features', '131807'], 'features')
# (['features', '126929'], 'features')
# (['features', '101595'], 'features')
# (['features', '139919'], 'features')
# (['features', '134915'], 'features')
# (['features', '245111'], 'features')
# (['features', '185088'], 'features')
# (['features', '195304'], 'features')
# (['features', '230806'], 'features')
# (['smooth', '210148'], 'features')
# (['features', '111499'], 'smooth')
# (['features', '165625'], 'smooth')
# (['smooth', '233217'], 'smooth')
# (['features', '242446'], 'features')
# (['smooth', '166381'], 'smooth')
# (['features', '168252'], 'features')
# (['features', '194849'], 'smooth')
# (['smooth', '169821'], 'smooth')
# (['features', '220802'], 'features')
# (['smooth', '234788'], 'smooth')
# (['features', '204338'], 'features')
# (['features', '216997'], 'smooth')
# (['features', '134568'], 'features')
# (['features', '192740'], 'smooth')
# (['features', '182250'], 'features')
# (['smooth', '199574'], 'smooth')
# (['smooth', '210972'], 'smooth')
# (['smooth', '131999'], 'smooth')
# (['smooth', '241164'], 'features')
# (['features', '109629'], 'features')
# (['features', '111791'], 'features')
# (['features', '205939'], 'features')
# (['smooth', '102822'], 'features')
# (['features', '127698'], 'smooth')
# (['features', '135258'], 'features')
# (['features', '226885'], 'features')
# (['features', '179246'], 'features')
# (['features', '116832'], 'features')
# (['features', '248461'], 'features')
# (['features', '134569'], 'features')
# (['features', '137841'], 'features')
# (['features', '144866'], 'features')
# (['smooth', '232917'], 'smooth')
# (['smooth', '105940'], 'features')
# (['smooth', '146743'], 'features')
# (['features', '234108'], 'features')
# (['smooth', '107510'], 'smooth')
# (['smooth', '181165'], 'smooth')
# (['smooth', '138238'], 'smooth')
# (['features', '156674'], 'smooth')
# (['features', '176434'], 'features')
# (['smooth', '177446'], 'features')
# (['features', '186954'], 'features')
# (['features', '196934'], 'features')
# (['features', '175909'], 'features')
# (['features', '136823'], 'features')
# (['smooth', '218717'], 'smooth')
# (['smooth', '101232'], 'features')
# (['features', '148077'], 'features')
# (['smooth', '191843'], 'smooth')
# (['features', '180133'], 'features')
# (['features', '145354'], 'features')
# (['features', '189965'], 'features')
# (['smooth', '227195'], 'smooth')
# (['features', '229591'], 'features')
# (['features', '143984'], 'features')
# (['smooth', '206152'], 'smooth')
# (['features', '223954'], 'features')
# (['features', '244666'], 'features')
# (['features', '180165'], 'features')
# (['smooth', '128485'], 'smooth')
# (['smooth', '188995'], 'smooth')
# (['smooth', '115545'], 'smooth')
# (['smooth', '228891'], 'smooth')
# (['smooth', '123141'], 'smooth')
# (['features', '123349'], 'features')
# (['smooth', '227377'], 'features')
# (['features', '235168'], 'features')
# (['smooth', '116815'], 'features')
# (['smooth', '164609'], 'smooth')
# (['features', '195483'], 'smooth')
# (['features', '188093'], 'features')
# (['smooth', '211770'], 'smooth')
# (['features', '121178'], 'features')
# (['smooth', '142905'], 'smooth')
# (['features', '138616'], 'smooth')
# (['features', '199568'], 'features')
# (['features', '222208'], 'features')
# (['features', '162829'], 'smooth')
# (['smooth', '247865'], 'smooth')
# (['smooth', '138098'], 'smooth')
# (['features', '223012'], 'features')
# (['features', '121378'], 'features')
# (['features', '147971'], 'features')
# (['features', '132062'], 'features')
# (['features', '140776'], 'features')
# (['features', '162702'], 'features')
# (['features', '226369'], 'features')
# (['features', '236691'], 'features')
# (['features', '214833'], 'features')
# (['features', '142274'], 'features')
# (['features', '191538'], 'features')
# (['features', '106670'], 'features')
# (['features', '149785'], 'features')
# (['smooth', '205075'], 'smooth')
# (['features', '186962'], 'features')
# (['smooth', '148702'], 'smooth')
# (['features', '242534'], 'smooth')
# (['features', '109946'], 'features')
# (['smooth', '145215'], 'smooth')
# (['features', '157247'], 'features')
# (['smooth', '233845'], 'smooth')
# (['smooth', '243885'], 'smooth')
# (['features', '172760'], 'features')
# (['smooth', '210994'], 'smooth')
# (['smooth', '245825'], 'smooth')
# (['smooth', '227634'], 'smooth')
# (['features', '185725'], 'features')
# (['smooth', '232177'], 'features')
# (['smooth', '225852'], 'features')
# (['features', '126547'], 'features')
# (['smooth', '212559'], 'smooth')
# (['features', '226487'], 'features')
# (['features', '109868'], 'features')
# (['features', '201548'], 'features')
# (['features', '107055'], 'smooth')
# (['features', '170659'], 'features')
# (['features', '229218'], 'features')
# (['features', '125686'], 'smooth')
# (['features', '182348'], 'smooth')
# (['features', '215019'], 'features')
# (['smooth', '176981'], 'smooth')
# (['features', '168615'], 'smooth')
# (['smooth', '224338'], 'smooth')
# (['smooth', '139523'], 'smooth')
# (['smooth', '230272'], 'smooth')
# (['smooth', '237414'], 'smooth')
# (['features', '180239'], 'features')
# (['features', '158193'], 'features')
# (['features', '211598'], 'features')
# (['features', '248014'], 'features')
# (['features', '208322'], 'features')
# (['smooth', '130745'], 'smooth')
# (['smooth', '216988'], 'smooth')
# (['smooth', '177390'], 'smooth')
# (['smooth', '205711'], 'smooth')
# (['features', '230423'], 'features')
# (['features', '147748'], 'features')
# (['smooth', '198510'], 'smooth')
# (['smooth', '206599'], 'smooth')
# (['smooth', '139008'], 'features')
# (['features', '124494'], 'features')
# (['smooth', '246642'], 'features')
# (['features', '149463'], 'smooth')
# (['features', '185049'], 'features')
# (['features', '192523'], 'features')
# (['features', '165083'], 'features')
# (['features', '169906'], 'features')
# (['smooth', '180682'], 'smooth')
# (['features', '192911'], 'smooth')
# (['smooth', '241065'], 'features')
# (['features', '102474'], 'features')
# (['features', '237212'], 'features')
# (['smooth', '139220'], 'features')
# (['features', '208046'], 'features')
# (['features', '211947'], 'features')
# (['smooth', '188672'], 'smooth')
# (['features', '149771'], 'features')
# (['smooth', '152647'], 'smooth')
# (['features', '126132'], 'features')
# (['smooth', '205781'], 'smooth')
# (['features', '164903'], 'features')
# (['smooth', '212585'], 'smooth')
# (['features', '243382'], 'features')
# (['features', '162249'], 'smooth')
# (['features', '138899'], 'smooth')
# (['features', '235460'], 'features')
# (['features', '149509'], 'features')
# (['features', '221242'], 'smooth')
# (['smooth', '150333'], 'smooth')
# (['smooth', '138341'], 'smooth')
# (['smooth', '237113'], 'smooth')
# (['smooth', '175812'], 'smooth')
# (['features', '246144'], 'features')
# (['smooth', '180047'], 'smooth')
# (['smooth', '161812'], 'features')
# (['features', '194722'], 'features')
# (['features', '223965'], 'features')
# (['smooth', '103191'], 'smooth')
# (['features', '217809'], 'features')
# (['features', '224214'], 'smooth')
# (['smooth', '162195'], 'smooth')
# (['features', '224382'], 'features')
# (['smooth', '202090'], 'features')
# (['features', '232749'], 'features')
# (['smooth', '190335'], 'smooth')
# (['smooth', '112846'], 'smooth')
# (['smooth', '214969'], 'smooth')
# (['features', '189844'], 'smooth')
# (['features', '184375'], 'features')
# (['smooth', '119186'], 'smooth')
# (['smooth', '186308'], 'smooth')
# (['features', '195679'], 'features')
# (['features', '148734'], 'smooth')
# (['smooth', '100458'], 'smooth')
# (['smooth', '170173'], 'smooth')
# (['features', '133178'], 'features')
# (['smooth', '223340'], 'smooth')
# (['smooth', '185095'], 'smooth')
# (['features', '226757'], 'features')
# (['features', '173198'], 'features')
# (['smooth', '156978'], 'features')
# (['features', '130334'], 'features')
# (['smooth', '134631'], 'smooth')
# (['smooth', '110480'], 'smooth')
# (['features', '104540'], 'features')
# (['features', '131021'], 'features')
# (['features', '140023'], 'features')
# (['features', '184309'], 'features')
# (['smooth', '236301'], 'features')
# (['features', '169507'], 'features')
# (['features', '165383'], 'features')
# (['features', '139480'], 'features')
# (['smooth', '118506'], 'smooth')
# (['smooth', '128864'], 'smooth')
# (['smooth', '189113'], 'smooth')
# (['smooth', '156109'], 'smooth')
# (['features', '174318'], 'features')
# (['smooth', '211294'], 'smooth')
# (['features', '143148'], 'features')
# (['smooth', '200245'], 'smooth')
# (['features', '202048'], 'features')
# (['features', '219515'], 'smooth')
# (['features', '196142'], 'smooth')
# (['features', '134676'], 'features')
# (['smooth', '205745'], 'smooth')
# (['features', '230010'], 'features')
# (['smooth', '147261'], 'smooth')
# (['features', '143798'], 'features')
# (['features', '212232'], 'features')
# (['smooth', '224661'], 'smooth')
# (['smooth', '123713'], 'smooth')
# (['smooth', '103224'], 'smooth')
# (['smooth', '224916'], 'features')
# (['features', '224736'], 'features')
# (['features', '167104'], 'features')
# (['features', '211857'], 'smooth')
# (['features', '141149'], 'features')
# (['features', '182971'], 'features')
# (['smooth', '238917'], 'smooth')
# (['smooth', '150353'], 'features')
# (['features', '214187'], 'features')
# (['features', '232442'], 'smooth')
# (['smooth', '136167'], 'smooth')
# (['features', '143636'], 'smooth')
# (['smooth', '233944'], 'smooth')
# (['features', '128724'], 'smooth')
# (['smooth', '130768'], 'smooth')
# (['features', '171238'], 'features')
# (['smooth', '141148'], 'smooth')
# (['features', '101718'], 'features')
# (['features', '163699'], 'features')
# (['smooth', '195352'], 'features')
# (['features', '184305'], 'features')
# (['smooth', '157309'], 'features')
# (['features', '198091'], 'smooth')
# (['smooth', '161232'], 'smooth')
# (['smooth', '116669'], 'smooth')
# (['features', '196617'], 'features')
# (['smooth', '165341'], 'smooth')
# (['smooth', '151639'], 'smooth')
# (['features', '165326'], 'features')
# (['features', '135187'], 'features')
# (['features', '112034'], 'features')
# (['features', '166262'], 'features')
# (['smooth', '197431'], 'smooth')
# (['smooth', '238899'], 'smooth')
# (['smooth', '113267'], 'smooth')
# (['features', '196191'], 'features')
# (['smooth', '199689'], 'smooth')
# (['smooth', '154923'], 'smooth')
# (['smooth', '173648'], 'smooth')
# (['smooth', '178136'], 'smooth')
# (['smooth', '138916'], 'smooth')
# (['features', '152129'], 'features')
# (['features', '130343'], 'features')
# (['features', '202502'], 'features')
# (['features', '119009'], 'features')
# (['features', '164254'], 'features')
# (['features', '220659'], 'smooth')
# (['features', '114080'], 'features')
# (['smooth', '167951'], 'smooth')
# (['smooth', '184674'], 'smooth')
# (['features', '120548'], 'features')
# (['smooth', '108928'], 'smooth')
# (['features', '204959'], 'smooth')
# (['features', '171971'], 'features')
# (['smooth', '146256'], 'smooth')
# (['features', '205079'], 'features')
# (['smooth', '169651'], 'smooth')
# (['features', '227018'], 'features')
# (['features', '233459'], 'features')
# (['features', '210760'], 'features')
# (['smooth', '164760'], 'smooth')
# (['smooth', '223521'], 'smooth')
# (['features', '193877'], 'features')
# (['features', '150004'], 'features')
# (['features', '150670'], 'features')
# (['features', '228376'], 'features')
# (['features', '123475'], 'features')
# (['features', '115571'], 'features')
# (['smooth', '102839'], 'smooth')
# (['features', '226351'], 'features')
# (['smooth', '171487'], 'smooth')
# (['smooth', '178106'], 'smooth')
# (['smooth', '240064'], 'smooth')
# (['features', '138217'], 'features')
# (['features', '191932'], 'features')
# (['smooth', '179592'], 'smooth')
# (['features', '103246'], 'features')
# (['smooth', '222251'], 'smooth')
# (['features', '186287'], 'features')
# (['features', '104440'], 'smooth')
# (['smooth', '170606'], 'features')
# (['features', '124548'], 'features')
# (['features', '148826'], 'smooth')
# (['smooth', '165389'], 'smooth')
# (['features', '104830'], 'features')
# (['features', '172075'], 'smooth')
# (['smooth', '176633'], 'smooth')
# (['smooth', '136851'], 'smooth')
# (['features', '150500'], 'features')
# (['smooth', '218735'], 'smooth')
# (['features', '145875'], 'features')
# (['smooth', '158119'], 'features')
# (['smooth', '139955'], 'smooth')
# (['features', '110566'], 'features')
# (['features', '152141'], 'features')
# (['features', '126475'], 'smooth')
# (['smooth', '191388'], 'smooth')
# (['smooth', '212474'], 'smooth')
# (['smooth', '228321'], 'smooth')
# (['smooth', '113149'], 'smooth')
# (['features', '130741'], 'features')
# (['smooth', '147218'], 'smooth')
# (['smooth', '227090'], 'smooth')
# (['smooth', '157009'], 'features')
# (['features', '145453'], 'features')
# (['features', '205525'], 'features')
# (['features', '156541'], 'features')
# (['smooth', '246821'], 'smooth')
# (['smooth', '231719'], 'smooth')
# (['features', '149812'], 'features')
# (['features', '149658'], 'features')
# (['smooth', '117104'], 'smooth')
# (['features', '125123'], 'features')
# (['features', '222563'], 'features')
# (['smooth', '161798'], 'smooth')
# (['features', '172845'], 'smooth')
# (['features', '239186'], 'smooth')
# (['features', '204634'], 'features')
# (['features', '156698'], 'features')
# (['features', '128004'], 'features')
# (['smooth', '123118'], 'smooth')
# (['features', '167856'], 'features')
# (['smooth', '234705'], 'smooth')
# (['features', '127918'], 'features')
# (['smooth', '122933'], 'smooth')
# (['features', '147811'], 'features')
# (['features', '139275'], 'features')
# (['smooth', '151678'], 'smooth')
# (['features', '135295'], 'features')
# (['features', '175024'], 'features')
# (['features', '109215'], 'smooth')
# (['smooth', '162926'], 'smooth')
# (['smooth', '138532'], 'smooth')
# (['features', '232906'], 'features')
# (['features', '123692'], 'features')
# (['smooth', '199261'], 'smooth')
# (['smooth', '198931'], 'features')
# (['features', '171031'], 'features')
# (['smooth', '101247'], 'smooth')
# (['smooth', '121611'], 'smooth')
# (['smooth', '131525'], 'smooth')
# (['smooth', '110805'], 'smooth')
# (['smooth', '201411'], 'smooth')
# (['smooth', '113857'], 'smooth')
# (['features', '136109'], 'features')
# (['features', '220684'], 'features')
# (['smooth', '155530'], 'smooth')
# (['features', '170676'], 'features')
# (['smooth', '214991'], 'smooth')
# (['smooth', '197862'], 'smooth')
# (['smooth', '209819'], 'smooth')
# (['smooth', '147159'], 'smooth')
# (['features', '202316'], 'features')
# (['features', '141604'], 'smooth')
# (['features', '129486'], 'features')
# (['smooth', '221470'], 'smooth')
# (['features', '182054'], 'smooth')
# (['smooth', '194611'], 'smooth')
# (['smooth', '115662'], 'features')
# (['smooth', '183365'], 'smooth')
# (['features', '180846'], 'smooth')
# (['smooth', '247242'], 'smooth')
# (['smooth', '141962'], 'features')
# (['features', '107197'], 'features')
# (['features', '233269'], 'features')
# (['smooth', '175866'], 'features')
# (['smooth', '147444'], 'features')
# (['features', '101325'], 'smooth')
# (['features', '167305'], 'smooth')
# (['features', '131211'], 'smooth')
# (['smooth', '243150'], 'smooth')
# (['features', '200801'], 'features')
# (['smooth', '162813'], 'smooth')
# (['smooth', '102347'], 'smooth')
# (['features', '101166'], 'features')
# (['smooth', '247473'], 'smooth')
# (['smooth', '139202'], 'smooth')
# (['smooth', '124305'], 'smooth')
# (['smooth', '192497'], 'smooth')
# (['features', '193493'], 'features')
# (['features', '170168'], 'features')
# (['features', '131138'], 'features')
# (['smooth', '233333'], 'smooth')
# (['features', '184168'], 'features')
# (['features', '167288'], 'features')
# (['features', '182387'], 'features')
# (['features', '160936'], 'smooth')
# (['features', '218281'], 'smooth')
# (['features', '180124'], 'features')
# (['features', '180838'], 'smooth')
# (['smooth', '245304'], 'smooth')
# (['features', '151686'], 'features')
# (['features', '131374'], 'smooth')
# (['smooth', '208805'], 'features')
# (['features', '237354'], 'features')
# (['features', '190362'], 'features')
# (['features', '114570'], 'features')
# (['features', '206330'], 'smooth')
# (['smooth', '175192'], 'smooth')
# (['features', '219431'], 'features')
# (['smooth', '233191'], 'features')
# (['smooth', '206430'], 'features')
# (['features', '178644'], 'features')
# (['smooth', '149992'], 'smooth')
# (['features', '206537'], 'smooth')
# (['features', '105762'], 'smooth')
# (['features', '175524'], 'features')
# (['smooth', '161858'], 'smooth')
# (['smooth', '161891'], 'smooth')
# (['smooth', '143316'], 'features')
# (['smooth', '212849'], 'smooth')
# (['features', '240296'], 'features')
# (['features', '143485'], 'features')
# (['smooth', '198462'], 'smooth')
# (['features', '100740'], 'smooth')
# (['smooth', '217843'], 'smooth')
# (['features', '209240'], 'features')
# (['features', '206017'], 'features')
# (['smooth', '181618'], 'smooth')
# (['smooth', '163697'], 'smooth')
# (['features', '150493'], 'features')
# (['features', '134604'], 'features')
# (['features', '129149'], 'features')
# (['smooth', '134638'], 'smooth')
# (['features', '170599'], 'features')
# (['smooth', '128496'], 'smooth')
# (['features', '223636'], 'features')
# (['features', '239828'], 'features')
# (['smooth', '162210'], 'smooth')
# (['features', '184782'], 'features')
# (['smooth', '101092'], 'smooth')
# (['features', '149483'], 'smooth')
# (['features', '199490'], 'features')
# (['features', '219298'], 'features')
# (['features', '114026'], 'features')
# (['features', '160613'], 'features')
# (['features', '137179'], 'features')
# (['features', '193741'], 'features')
# (['features', '194789'], 'features')
# (['features', '114236'], 'features')
# (['smooth', '147845'], 'smooth')
# (['features', '172145'], 'features')
# (['features', '217771'], 'features')
# (['features', '168971'], 'features')
# (['smooth', '202730'], 'features')
# (['features', '123981'], 'features')
# (['smooth', '192765'], 'features')
# (['features', '141268'], 'features')
# (['features', '205658'], 'features')
# (['features', '113608'], 'features')
# (['features', '227808'], 'features')
# (['features', '108979'], 'features')
# (['smooth', '243106'], 'smooth')
# (['features', '245468'], 'features')
# (['features', '201997'], 'features')
# (['features', '178910'], 'features')
# (['features', '115840'], 'features')
# (['features', '215614'], 'features')
# (['features', '211908'], 'features')
# (['features', '153497'], 'features')
# (['features', '165140'], 'features')
# (['smooth', '135223'], 'smooth')
# (['features', '119967'], 'features')
# (['smooth', '135093'], 'features')
# (['features', '234051'], 'smooth')
# (['smooth', '230513'], 'smooth')
# (['smooth', '160623'], 'smooth')
# (['features', '171355'], 'features')
# (['smooth', '217931'], 'smooth')
# (['features', '114587'], 'features')
# (['features', '186767'], 'features')
# (['features', '106028'], 'smooth')
# (['features', '138306'], 'features')
# (['smooth', '151561'], 'smooth')
# (['features', '151845'], 'features')
# (['smooth', '160244'], 'features')
# (['features', '188135'], 'features')
# (['features', '116667'], 'features')
# (['features', '243418'], 'features')
# (['features', '245397'], 'features')
# (['smooth', '139444'], 'features')
# (['features', '126549'], 'features')
# (['features', '156493'], 'features')
# (['features', '226438'], 'features')
# (['smooth', '129439'], 'smooth')
# (['smooth', '187584'], 'smooth')
# (['features', '200044'], 'features')
# (['features', '139775'], 'smooth')
# (['features', '179791'], 'smooth')
# (['features', '132803'], 'features')
# (['features', '120716'], 'features')
# (['features', '198375'], 'features')
# (['features', '202428'], 'features')
# (['features', '213009'], 'smooth')
# (['features', '123024'], 'features')
# (['smooth', '243271'], 'smooth')
# ...
# (['smooth', '190485'], 'smooth')
# (['features', '226277'], 'features')
# (['smooth', '190143'], 'smooth')
# (['smooth', '208697'], 'smooth')
# (['features', '103503'], 'features')
# (['features', '163209'], 'features')
# (['features', '151252'], 'features')
# (['features', '184005'], 'features')
# (['smooth', '158520'], 'smooth')
# (['smooth', '123192'], 'smooth')
# (['features', '143976'], 'features')
# (['features', '132573'], 'features')
# (['features', '135208'], 'features')
# (['features', '171766'], 'features')
# (['smooth', '132139'], 'features')
# (['features', '163252'], 'features')
# (['features', '233421'], 'features')
# (['features', '176213'], 'features')
# (['features', '185906'], 'features')
# (['smooth', '181840'], 'smooth')
# (['features', '103547'], 'features')
# (['features', '187041'], 'features')
# (['features', '213840'], 'features')
# (['smooth', '149271'], 'smooth')
# (['features', '235529'], 'features')
# (['smooth', '158969'], 'smooth')
# (['smooth', '134347'], 'features')
# (['smooth', '176540'], 'smooth')
# (['features', '126856'], 'smooth')
# (['features', '100150'], 'features')
# (['features', '155346'], 'features')
# (['smooth', '190058'], 'smooth')
# (['smooth', '193777'], 'features')
# (['features', '233081'], 'features')
# (['smooth', '103626'], 'smooth')
# (['features', '160204'], 'features')
# (['features', '190526'], 'features')
# (['features', '244636'], 'smooth')
# (['smooth', '220783'], 'smooth')
# (['features', '142903'], 'features')
# (['features', '192588'], 'features')
# (['smooth', '197903'], 'smooth')
# (['features', '134947'], 'features')
# (['features', '188923'], 'features')
# (['features', '151546'], 'features')
# (['features', '113436'], 'features')
# (['smooth', '217354'], 'features')
# (['features', '161243'], 'features')
# (['features', '153680'], 'features')
# (['features', '207798'], 'features')
# (['features', '120676'], 'features')
# (['smooth', '158199'], 'smooth')
# (['features', '193101'], 'features')
# (['features', '162974'], 'features')
# (['features', '162911'], 'features')
# (['features', '140012'], 'features')
# (['features', '144324'], 'features')
# (['smooth', '115938'], 'smooth')
# (['features', '215112'], 'features')
# (['features', '121031'], 'features')
# (['features', '169850'], 'smooth')
# (['features', '125672'], 'features')
# (['smooth', '178945'], 'smooth')
# (['features', '192593'], 'features')
# (['features', '142290'], 'features')
# (['features', '233241'], 'features')
# (['features', '204724'], 'smooth')
# (['smooth', '220322'], 'smooth')
# (['smooth', '245993'], 'smooth')
# (['features', '148257'], 'features')
# (['smooth', '194623'], 'features')
# (['smooth', '147459'], 'smooth')
# (['smooth', '133985'], 'features')
# (['smooth', '120258'], 'smooth')
# (['features', '175001'], 'features')
# (['smooth', '122946'], 'features')
# (['smooth', '112135'], 'smooth')
# (['smooth', '138610'], 'features')
# (['features', '139758'], 'features')
# (['features', '165305'], 'features')
# (['features', '191877'], 'smooth')
# (['features', '212409'], 'features')
# (['features', '214577'], 'features')
# (['smooth', '183091'], 'features')
# (['features', '216785'], 'features')
# (['features', '148766'], 'features')
# (['smooth', '195504'], 'features')
# (['smooth', '117206'], 'features')
# (['features', '137412'], 'features')
# (['smooth', '139046'], 'smooth')
# (['smooth', '190212'], 'smooth')
# (['features', '161253'], 'features')
# (['features', '137845'], 'features')
# (['smooth', '194113'], 'smooth')
# (['features', '121902'], 'features')
# (['smooth', '182213'], 'features')
# (['features', '177315'], 'features')
# (['features', '139596'], 'features')
# (['features', '166775'], 'features')
# (['features', '221696'], 'features')
# (['features', '187024'], 'smooth')
# (['smooth', '116517'], 'smooth')
# (['smooth', '169695'], 'smooth')
# (['features', '128703'], 'features')
# (['features', '159015'], 'features')
# (['smooth', '241853'], 'smooth')
# (['features', '102422'], 'features')
# (['features', '132919'], 'features')
# (['smooth', '117135'], 'features')
# (['features', '150590'], 'smooth')
# (['smooth', '209908'], 'smooth')
# (['features', '203576'], 'features')
# (['smooth', '218587'], 'smooth')
# (['features', '217161'], 'features')
# (['features', '128646'], 'features')
# (['features', '174264'], 'smooth')
# (['smooth', '102471'], 'smooth')
# (['features', '179166'], 'smooth')
# (['features', '242148'], 'features')
# (['features', '154067'], 'features')
# (['smooth', '171979'], 'smooth')
# (['smooth', '103819'], 'smooth')
# (['features', '177085'], 'features')
# (['features', '150199'], 'features')
# (['features', '141511'], 'smooth')
# (['smooth', '133023'], 'features')
# (['features', '167426'], 'smooth')
# (['features', '220231'], 'features')
# (['features', '187310'], 'smooth')
# (['features', '107229'], 'features')
# (['features', '180830'], 'features')
# (['features', '154322'], 'smooth')
# (['features', '209192'], 'features')
# (['features', '130077'], 'features')
# (['features', '170259'], 'smooth')
# (['features', '112479'], 'features')
# (['features', '246785'], 'features')
# (['features', '144770'], 'features')
# (['smooth', '192570'], 'smooth')
# (['smooth', '163256'], 'smooth')
# (['features', '182612'], 'features')
# (['features', '135174'], 'features')
# (['features', '155743'], 'features')
# (['features', '131051'], 'smooth')
# (['features', '132814'], 'features')
# (['features', '110521'], 'features')
# (['features', '117996'], 'smooth')
# (['features', '176864'], 'smooth')
# (['smooth', '104934'], 'features')
# (['smooth', '210574'], 'smooth')
# (['features', '176789'], 'features')
# (['features', '245294'], 'smooth')
# (['smooth', '224270'], 'features')
# (['smooth', '216090'], 'smooth')
# (['features', '192058'], 'smooth')
# (['features', '217194'], 'smooth')
# (['features', '123470'], 'features')
# (['features', '214626'], 'features')
# (['features', '195109'], 'features')
# (['smooth', '181740'], 'features')
# (['smooth', '216107'], 'smooth')
# (['smooth', '243581'], 'smooth')
# (['features', '212720'], 'features')
# (['features', '141901'], 'smooth')
# (['features', '171499'], 'features')
# (['features', '101564'], 'features')
# (['features', '242525'], 'features')
# (['features', '233034'], 'features')
# (['smooth', '200599'], 'smooth')
# (['features', '226957'], 'features')
# (['features', '145898'], 'features')
# (['features', '161709'], 'features')
# (['features', '128271'], 'smooth')
# (['features', '188749'], 'smooth')
# (['features', '217752'], 'smooth')
# (['smooth', '205600'], 'smooth')
# (['features', '198877'], 'smooth')
# (['smooth', '169996'], 'features')
# (['features', '239282'], 'features')
# (['smooth', '156654'], 'features')
# (['features', '240671'], 'features')
# (['features', '141152'], 'features')
# (['features', '176068'], 'smooth')
# (['features', '205432'], 'features')
# (['smooth', '238723'], 'features')
# (['features', '230292'], 'smooth')
# (['features', '112824'], 'features')
# (['smooth', '116614'], 'smooth')
# (['smooth', '174124'], 'smooth')
# (['features', '159649'], 'features')
# (['features', '215297'], 'features')
# (['features', '183085'], 'features')
# (['features', '232174'], 'features')
# (['smooth', '122715'], 'smooth')
# (['smooth', '139692'], 'smooth')
# (['smooth', '212448'], 'features')
# (['features', '145951'], 'smooth')
# (['features', '146445'], 'features')
# (['smooth', '236775'], 'smooth')
# (['smooth', '209612'], 'smooth')
# (['features', '216226'], 'features')
# (['smooth', '137237'], 'smooth')
# (['features', '155041'], 'features')
# (['features', '184838'], 'features')
# (['features', '177859'], 'features')
# (['features', '233208'], 'features')
# (['smooth', '191577'], 'smooth')
# (['smooth', '222722'], 'smooth')
# (['features', '187981'], 'features')
# (['features', '101375'], 'features')
# (['features', '174709'], 'features')
# (['smooth', '131376'], 'smooth')
# (['smooth', '243126'], 'smooth')
# (['smooth', '186257'], 'smooth')
# (['smooth', '188440'], 'smooth')
# (['smooth', '193205'], 'smooth')
# (['features', '172709'], 'features')
# (['features', '146437'], 'features')
# (['features', '143056'], 'features')
# (['features', '178031'], 'smooth')
# (['features', '220972'], 'features')
# (['smooth', '187886'], 'smooth')
# (['smooth', '227997'], 'smooth')
# (['features', '161541'], 'features')
# (['features', '169162'], 'features')
# (['features', '162153'], 'features')
# (['features', '117240'], 'features')
# (['features', '156355'], 'features')
# (['smooth', '133036'], 'smooth')
# (['smooth', '140081'], 'smooth')
# (['features', '100561'], 'features')
# (['features', '153482'], 'features')
# (['smooth', '116140'], 'features')
# (['smooth', '140329'], 'smooth')
# (['features', '180253'], 'features')
# (['features', '142379'], 'features')
# (['smooth', '191762'], 'smooth')
# (['features', '215101'], 'features')
# (['smooth', '129570'], 'smooth')
# (['features', '208099'], 'features')
# (['features', '221571'], 'features')
# (['smooth', '174338'], 'smooth')
# (['smooth', '224405'], 'smooth')
# (['features', '119501'], 'features')
# (['smooth', '104703'], 'smooth')
# (['smooth', '214976'], 'smooth')
# (['features', '188184'], 'features')
# (['features', '243337'], 'features')
# (['features', '113470'], 'features')
# (['smooth', '143029'], 'smooth')
# (['features', '178276'], 'features')
# (['features', '126364'], 'features')
# (['smooth', '106040'], 'smooth')
# (['features', '148253'], 'features')
# (['smooth', '114696'], 'smooth')
# (['smooth', '100434'], 'smooth')
# (['features', '205219'], 'smooth')
# (['features', '223947'], 'smooth')
# (['features', '238946'], 'features')
# (['smooth', '114190'], 'smooth')
# (['features', '129191'], 'features')
# (['smooth', '223918'], 'smooth')
# (['features', '179182'], 'features')
# (['smooth', '212039'], 'features')
# (['smooth', '201606'], 'smooth')
# (['smooth', '167864'], 'features')
# (['features', '172407'], 'smooth')
# (['features', '215476'], 'features')
# (['features', '238045'], 'features')
# (['features', '126841'], 'smooth')
# (['smooth', '238586'], 'smooth')
# (['features', '182301'], 'smooth')
# (['features', '223668'], 'features')
# (['features', '222584'], 'features')
# (['smooth', '183817'], 'smooth')
# (['features', '116306'], 'features')
# (['smooth', '205291'], 'smooth')
# (['features', '225021'], 'features')
# (['features', '117158'], 'features')
# (['smooth', '203655'], 'features')
# (['features', '222985'], 'smooth')
# (['smooth', '214317'], 'features')
# (['smooth', '195556'], 'smooth')
# (['smooth', '237305'], 'smooth')
# (['smooth', '219416'], 'smooth')
# (['features', '212911'], 'features')
# (['features', '136441'], 'features')
# (['smooth', '210027'], 'smooth')
# (['smooth', '172306'], 'smooth')
# (['features', '133451'], 'smooth')
# (['features', '235605'], 'features')
# (['features', '170208'], 'features')
# (['smooth', '150021'], 'smooth')
# (['smooth', '160100'], 'smooth')
# (['smooth', '230651'], 'features')
# (['features', '114588'], 'smooth')
# (['smooth', '174904'], 'smooth')
# (['smooth', '201801'], 'smooth')
# (['smooth', '244598'], 'smooth')
# (['features', '119720'], 'smooth')
# (['smooth', '154801'], 'smooth')
# (['smooth', '104611'], 'smooth')
# (['features', '240670'], 'smooth')
# (['features', '231103'], 'features')
# (['features', '168921'], 'features')
# (['smooth', '124019'], 'smooth')
# (['smooth', '197317'], 'smooth')
# (['features', '165838'], 'smooth')
# (['smooth', '175894'], 'features')
# (['features', '177056'], 'features')
# (['smooth', '185585'], 'smooth')
# (['smooth', '160962'], 'features')
# (['features', '220800'], 'features')
# (['features', '118971'], 'features')
# (['smooth', '117764'], 'smooth')
# (['smooth', '114173'], 'smooth')
# (['smooth', '227454'], 'smooth')
# (['features', '228806'], 'features')
# (['features', '156023'], 'smooth')
# (['features', '156463'], 'features')
# (['smooth', '174037'], 'smooth')
# (['features', '175917'], 'smooth')
# (['features', '174635'], 'features')
# (['features', '108742'], 'features')
# (['features', '215332'], 'smooth')
# (['features', '139205'], 'smooth')
# (['features', '223253'], 'features')
# (['features', '241103'], 'smooth')
# (['features', '206676'], 'features')
# (['features', '129993'], 'features')
# (['smooth', '143447'], 'smooth')
# (['smooth', '145436'], 'features')
# (['features', '109380'], 'features')
# (['features', '189442'], 'smooth')
# (['features', '154101'], 'smooth')
# (['features', '128202'], 'features')
# (['smooth', '236979'], 'smooth')
# (['features', '236654'], 'smooth')
# (['features', '115716'], 'smooth')
# (['features', '188265'], 'smooth')
# (['smooth', '123679'], 'smooth')
# (['features', '110384'], 'features')
# (['features', '117017'], 'features')
# (['smooth', '238789'], 'smooth')
# (['smooth', '219495'], 'smooth')
# (['features', '221443'], 'smooth')
# (['features', '217914'], 'features')
# (['features', '181107'], 'features')
# (['features', '225801'], 'features')
# (['features', '191029'], 'features')
# (['features', '235710'], 'features')
# (['features', '138534'], 'features')
# (['features', '182837'], 'features')
# (['features', '114319'], 'smooth')
# (['features', '226360'], 'features')
# (['features', '231042'], 'smooth')
# (['smooth', '206012'], 'smooth')
# (['features', '106165'], 'features')
# (['features', '162557'], 'features')
# (['features', '202914'], 'smooth')
# (['features', '237562'], 'features')
# (['features', '229246'], 'features')
# (['features', '224007'], 'features')
# (['features', '146148'], 'features')
# (['smooth', '237040'], 'smooth')
# (['features', '158637'], 'features')
# (['features', '194472'], 'features')
# (['smooth', '219952'], 'smooth')
# (['smooth', '133231'], 'smooth')
# (['features', '161385'], 'smooth')
# (['features', '228519'], 'smooth')
# (['smooth', '175537'], 'smooth')
# (['features', '165342'], 'features')
# (['features', '223431'], 'features')
# (['smooth', '209321'], 'smooth')
# (['smooth', '116565'], 'smooth')
# (['features', '159832'], 'features')
# (['features', '217915'], 'features')
# (['smooth', '119384'], 'smooth')
# (['features', '171178'], 'features')
# (['features', '226342'], 'smooth')
# (['features', '100444'], 'smooth')
# (['smooth', '210032'], 'features')
# (['smooth', '170744'], 'smooth')
# (['features', '129376'], 'smooth')
# (['features', '245347'], 'features')
# (['smooth', '125393'], 'smooth')
# (['features', '136387'], 'smooth')
# (['features', '160144'], 'features')
# (['smooth', '120891'], 'smooth')
# (['smooth', '195712'], 'features')
# (['features', '124299'], 'features')
# (['smooth', '174395'], 'smooth')
# (['smooth', '101788'], 'features')
# (['smooth', '234119'], 'smooth')
# (['features', '154172'], 'features')
# (['features', '216373'], 'features')
# (['features', '113118'], 'smooth')
# (['smooth', '134618'], 'smooth')
# (['features', '221039'], 'features')
# (['smooth', '129605'], 'smooth')
# (['features', '204051'], 'features')
# (['smooth', '208508'], 'smooth')
# (['smooth', '166101'], 'smooth')
# (['features', '193886'], 'features')
# (['features', '194759'], 'features')
# (['features', '205747'], 'features')
# (['smooth', '193585'], 'smooth')
# (['features', '185050'], 'features')
# (['features', '215292'], 'features')
# (['smooth', '130355'], 'smooth')
# (['smooth', '128341'], 'smooth')
# (['features', '104008'], 'features')
# (['features', '127783'], 'features')
# (['features', '237366'], 'features')
# (['features', '149536'], 'smooth')
# (['smooth', '216599'], 'features')
# (['smooth', '228285'], 'features')
# (['smooth', '105772'], 'smooth')
# (['features', '214927'], 'features')
# (['smooth', '143377'], 'smooth')
# (['smooth', '122754'], 'smooth')
# (['smooth', '130868'], 'smooth')
# (['features', '159299'], 'features')
# (['smooth', '211603'], 'smooth')
# (['features', '146316'], 'features')
# (['smooth', '122292'], 'smooth')
# (['features', '126153'], 'features')
# (['smooth', '103900'], 'smooth')
# (['features', '120384'], 'features')
# (['features', '156726'], 'features')
# (['smooth', '172857'], 'features')
# (['features', '147718'], 'features')
# (['features', '213881'], 'features')
# (['features', '157161'], 'features')
# (['features', '194648'], 'features')
# (['features', '150785'], 'smooth')
# (['smooth', '134817'], 'features')
# (['features', '108051'], 'features')
# (['features', '227625'], 'features')
# (['smooth', '194878'], 'smooth')
# (['features', '245515'], 'features')
# (['features', '221262'], 'features')
# (['smooth', '196919'], 'smooth')
# (['features', '242305'], 'features')
# (['smooth', '176185'], 'smooth')
# (['smooth', '203623'], 'smooth')
# (['features', '232544'], 'features')
# (['features', '112438'], 'features')
# (['features', '195779'], 'smooth')
# (['features', '203063'], 'features')
# (['features', '204993'], 'smooth')

# %%
LEN = len(y_test_id)
SCORE = 0.0
for elem in range(LEN):
    if y_test_predict[elem] == y_test_v[elem]:
        SCORE = SCORE + 1
SCORE = float(SCORE)
print (SCORE/LEN)
# Out:
# 0.789408866995

# %%
fig = plt.figure()
d = clf.predict_proba(X_train)[:, 1]

y_train_v = np.array(y_train_v)

print(d[0:10])
print(y_train_v[0:10])
print(d[y_train_v == "features"])

plt.hist(d[y_train_v == "features"], bins=50, normed=True, color="b", alpha=0.5)
plt.hist(d[y_train_v == "smooth"], bins=50, normed=True, color="r", alpha=0.5)
#plt.hist(d[y_train_v == "point"], bins=50, normed=True, color="y", alpha=0.5)

plt.show()
# Out:
# [ 0.138  0.074  0.808  0.81   0.924  0.052  0.678  0.79   0.236  0.982]
# ['features' 'features' 'smooth' 'smooth' 'smooth' 'features' 'smooth'
#  'smooth' 'features' 'smooth']
# [ 0.138  0.074  0.052 ...,  0.272  0.062  0.172]

# %%
from sklearn.model_selection import validation_curve

# Evaluate parameter range in CV
param_range = range(2, 200)
param_name = "max_leaf_nodes"

train_scores, test_scores = validation_curve(
    RandomForestClassifier(), X, y2, 
    param_name=param_name, 
    param_range=param_range, cv=5, n_jobs=-1)

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot parameter VS estimated error
plt.xlabel(param_name)
plt.ylabel("score")
plt.xlim(min(param_range), max(param_range))
plt.plot(param_range, 1. - train_scores_mean, color="red", label="Training error")
plt.fill_between(param_range, 
                 1. - train_scores_mean + train_scores_std,
                 1. - train_scores_mean - train_scores_std,
                 alpha=0.2, color="red")
plt.plot(param_range, 1. - test_scores_mean, color="blue", label="CV error")
plt.fill_between(param_range, 
                 1. - test_scores_mean + test_scores_std,
                 1. - test_scores_mean - test_scores_std, 
                 alpha=0.2, color="blue")
plt.legend(loc="best")
